# %% [markdown]
# # list
# a=[1,2,3,4,5]
# print(a)
# print(type(a))
#
# # empty lists and adding items
# b=[]
# print(b)
# b.append(101)
# b.append('Ram')
# b.append(20.5)
# print(b)

# %%
# iterating over list items
for items in b:
    print(items)

# %%
#sorting 
list=[10,3,2,5,6,22,13]
list.sort()
list[0]=12 #list items can be modified
print(list)
list.sort()
print(list)

# tuple
tup=(1,2,3,4,5,6)
print(type(tup))
# tup[0]=10   #tuple items can't be modified
print(tup)

# %%
# set list and tuples

list=[1,1,2,2]
tup=(1,1,2,2)
set={1,1,2,2}
print(list)
print(tup)
print(set)  #list and tuple supports duplicate data but not set

# %%
# dictionary
mydict={'hello':1,'prog':2,'text':3}
print(mydict)
for key in mydict:
    if mydict[key]==2:
        print(key,mydict[key])

# %%
# numpy 
import numpy as np
print(np.__version__)

arr=np.arange(1,20)
print(arr)

a=np.array([[1,2,3,4],[6,7,8,9]])
print(a)

# %%
import numpy as np
a=np.array([[1,2,3,4,5,6],[6,7,8,9,10,11]])
matrix=np.copy(a.reshape(4,3))
print(matrix)

# %%
# import random
mat1=np.random.randint(10,50,(2,2))
mat2=np.random.randint(10,50,(2,2))
print(mat1)
print(mat2)
print("---")
print(mat1+mat2)

# %%
pip install pandas

# %%
import pandas as pd
print(pd.__version__)
df=pd.read_csv("pandaCSV/grammy.csv")
print(df.head)
# Out:
# 2.2.3
# <bound method NDFrame.head of        year  annual_edition                      category  \
# 0      2024              67             Album Of The Year
# 1      2024              67             Album Of The Year
# 2      2024              67            Record Of The Year
# 3      2024              67            Record Of The Year
# 4      2024              67            Record Of The Year
# ...     ...             ...                           ...
# 25364  1958               1             Album Of The Year
# 25365  1958               1             Album Of The Year
# 25366  1958               1  Best Vocal Performance, Male
# 25367  1958               1  Best Vocal Performance, Male
# 25368  1958               1  Best Vocal Performance, Male
#
#                                                   artist  \
# 0      Jack Antonoff, Aaron Dessner & Taylor Swift, p...
# 1                                                Beyoncé
# 2      Giles Martin & Paul McCartney, producers; Geof...
# 3      Beyoncé, Nate Ferraro, Killah B & Raphael Saad...
# 4      Julian Bunetta, producer; Julian Bunetta & Jef...
# ...                                                  ...
# 25364                                                NaN
# 25365                                                NaN
# 25366                                         Perry Como
# 25367                                                NaN
# 25368                                                NaN
#
#                                            song_or_album  winner  \
# 0                          THE TORTURED POETS DEPARTMENT   False
# 1                                          COWBOY CARTER    True
# 2                                           Now And Then   False
# 3                                         TEXAS HOLD 'EM   False
# 4                                               Espresso   False
# ...                                                  ...     ...
# 25364                            Only The Lonely (Album)   False
# 25365  Ella Fitzgerald Sings The Irving Berlin Song B...   False
# 25366                               Catch A Falling Star    True
# 25367                                Witchcraft (Single)   False
# 25368           Nel Blu Dipinto Di Blu (Volare) (Single)   False
#
#                                                      url
# 0      https://www.grammy.com/awards/67th-annual-gram...
# 1      https://www.grammy.com/awards/67th-annual-gram...
# 2      https://www.grammy.com/awards/67th-annual-gram...
# 3      https://www.grammy.com/awards/67th-annual-gram...
# 4      https://www.grammy.com/awards/67th-annual-gram...
# ...                                                  ...
# 25364  https://www.grammy.com/awards/1st-annual-gramm...
# 25365  https://www.grammy.com/awards/1st-annual-gramm...
# 25366  https://www.grammy.com/awards/1st-annual-gramm...
# 25367  https://www.grammy.com/awards/1st-annual-gramm...
# 25368  https://www.grammy.com/awards/1st-annual-gramm...
#
# [25369 rows x 7 columns]>

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learnNote: you may need to restart the kernel to use updated packages.
#
#   Downloading scikit_learn-1.6.1-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\ussr\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (2.0.0)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.15.2-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp310-cp310-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    -------- ------------------------------- 2.4/11.1 MB 15.0 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 43.0 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 43.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 14.2 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scipy-1.15.2-cp310-cp310-win_amd64.whl (41.2 MB)
#    ---------------------------------------- 0.0/41.2 MB ? eta -:--:--
#    ------ --------------------------------- 6.8/41.2 MB 35.0 MB/s eta 0:00:01
#    ------------ --------------------------- 13.1/41.2 MB 35.8 MB/s eta 0:00:01
#    --------------- ------------------------ 16.0/41.2 MB 25.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 18.1/41.2 MB 24.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 18.4/41.2 MB 17.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 18.4/41.2 MB 17.3 MB/s eta 0:00:02
#    ------------------ --------------------- 18.6/41.2 MB 13.1 MB/s eta 0:00:02
#    ------------------ --------------------- 18.9/41.2 MB 11.8 MB/s eta 0:00:02
#    ------------------- -------------------- 19.7/41.2 MB 10.4 MB/s eta 0:00:03
#    -------------------- ------------------- 21.0/41.2 MB 10.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 23.3/41.2 MB 10.0 MB/s eta 0:00:02
#    -------------------------- ------------- 27.3/41.2 MB 10.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 35.9/41.2 MB 13.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 35.9/41.2 MB 13.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 36.2/41.2 MB 11.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 36.7/41.2 MB 10.9 MB/s eta 0:00:01
#    ------------------------------------ --- 37.2/41.2 MB 10.5 MB/s eta 0:00:01
#    ------------------------------------- -- 38.8/41.2 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------  40.4/41.2 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 41.2/41.2 MB 4.9 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 scipy-1.15.2 threadpoolctl-3.6.0

# %%
from sklearn.datasets import load_iris
import pandas as pd
iris=load_iris()
data=pd.DataFrame(data=iris.data,columns=iris.feature_names)
data['target']=iris.target
print(data.head)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from scikitlearn.datasets import load_iris
#       2 import pandas as pd
#       3 iris=load_iris()
#
# ModuleNotFoundError: No module named 'scikitlearn'

# %%
pip freeze
# Out:
# anyio==4.9.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asgiref==3.7.2
# asttokens==3.0.0
# async-lru==2.0.5
# attrs==25.3.0
# babel==2.17.0
# beautifulsoup4==4.13.3
# binaryornot==0.4.4
# bleach==6.2.0
# caer==2.0.8
# certifi==2025.1.31
# cffi==1.17.1
# chardet==5.2.0
# charset-normalizer==3.4.1
# click==8.1.8
# colorama==0.4.6
# comm==0.2.2
# contourpy==1.2.1
# cookiecutter==2.6.0
# cycler==0.12.1
# debugpy==1.8.13
# decorator==5.2.1
# defusedxml==0.7.1
# Django==5.0.3
# django-appconf==1.1.0
# django-browser-reload==1.18.0
# django-compressor==4.5.1
# django-tailwind==3.8.0
# exceptiongroup==1.2.2
# executing==2.2.0
# fastjsonschema==2.21.1
# fonttools==4.53.1
# fqdn==1.5.1
# h11==0.14.0
# httpcore==1.0.7
# httpx==0.28.1
# idna==3.10
# ipykernel==6.29.5
# ipython==8.34.0
# isoduration==20.11.0
# jedi==0.19.2
# Jinja2==3.1.5
# joblib==1.4.2
# json5==0.10.0
# jsonpointer==3.0.0
# jsonschema==4.23.0
# jsonschema-specifications==2024.10.1
# jupyter-events==0.12.0
# jupyter-lsp==2.2.5
# jupyter_client==8.6.3
# jupyter_core==5.7.2
# jupyter_server==2.15.0
# jupyter_server_terminals==0.5.3
# jupyterlab==4.3.6
# jupyterlab_pygments==0.3.0
# jupyterlab_server==2.27.3
# kiwisolver==1.4.5
# manage.py==0.2.10
# markdown-it-py==3.0.0
# MarkupSafe==3.0.2
# matplotlib==3.9.1
# matplotlib-inline==0.1.7
# mdurl==0.1.2
# mistune==3.1.3
# mypy==1.10.1
# mypy-extensions==1.0.0
# nbclient==0.10.2
# nbconvert==7.16.6
# nbformat==5.10.4
# nest-asyncio==1.6.0
# notebook==7.3.3
# notebook_shim==0.2.4
# numpy==2.0.0
# opencv-contrib-python==4.10.0.84
# overrides==7.7.0
# packaging==24.1
# pandas==2.2.3
# pandocfilters==1.5.1
# parso==0.8.4
# pillow==10.4.0
# platformdirs==4.3.7
# prometheus_client==0.21.1
# prompt_toolkit==3.0.50
# psutil==7.0.0
# pure_eval==0.2.3
# pycparser==2.22
# Pygments==2.19.1
# pyparsing==3.1.2
# pysketch==1.2
# python-dateutil==2.9.0.post0
# python-json-logger==3.3.0
# python-slugify==8.0.4
# pytz==2025.2
# pywin32==310
# pywinpty==2.0.15
# PyYAML==6.0.2
# pyzmq==26.3.0
# rcssmin==1.1.2
# referencing==0.36.2
# requests==2.32.3
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rich==13.9.4
# rjsmin==1.2.2
# rpds-py==0.23.1
# scikit-learn==1.6.1
# scipy==1.15.2
# Send2Trash==1.8.3
# six==1.16.0
# sniffio==1.3.1
# soupsieve==2.6
# sqlparse==0.4.4
# stack-data==0.6.3
# terminado==0.18.1
# text-unidecode==1.3
# threadpoolctl==3.6.0
# tinycss2==1.4.0
# tomli==2.0.1
# tornado==6.4.2
# traitlets==5.14.3
# types-python-dateutil==2.9.0.20241206
# typing_extensions==4.10.0
# tzdata==2024.1
# uri-template==1.3.0
# urllib3==2.3.0
# wcwidth==0.2.13
# webcolors==24.11.1
# webencodings==0.5.1
# websocket-client==1.8.0
# Note: you may need to restart the kernel to use updated packages.
